# %%
import stats
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('/Users/kjams/Desktop/generalized_model/data/nyc.csv')

# %%
agent = stats.formulas(df)
agent.set_x_y('Poverty','ChildPoverty')

# %%
x = agent.df['Black'].tolist()
y = agent.df['Unemployment'].tolist()
agent.linear_regression(x,y,50)
# Out:
# m = 0.0690490689246178
# b = 8.11995607148069
# array([ 7.42946538,  8.33324097,  9.23701656, 10.14079216, 11.04456775,
#        11.94834334, 12.85211893, 13.75589452, 14.65967011, 15.5634457 ])
