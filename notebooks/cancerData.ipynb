# %%
import stats
import scipy.io
import numpy as np
import scipy as sp
import scanpy as sc
import pandas as pd
import matplotlib.pyplot as plt

# %%
mtx_file = sp.io.mmread('DLBCL1/matrix.mtx')
dense_matrix = mtx_file.toarray()

# %%
genes = pd.read_csv("DLBCL1/genes.tsv", delimiter="\t", index_col=0, header=None, names=["gene_name"])
barcodes = pd.read_csv("DLBCL1/barcodes.tsv", delimiter="\t", index_col=0, header=None, names=["barcode"])

# %%
df = pd.DataFrame(dense_matrix, index=genes.index, columns=barcodes.index)

# %%
df.head(5)
# Out:
# barcode          AAACCTGAGCCATCGC-1  AAACCTGAGCCTTGAT-1  AAACCTGAGTTCGCAT-1  \
# ENSG00000243485                   0                   0                   0
# ENSG00000237613                   0                   0                   0
# ENSG00000186092                   0                   0                   0
# ENSG00000238009                   0                   0                   0
# ENSG00000239945                   0                   0                   0
#
# barcode          AAACCTGCACCACCAG-1  AAACCTGGTTAAGATG-1  AAACCTGGTTAAGGGC-1  \
# ENSG00000243485                   0                   0                   0
# ENSG00000237613                   0                   0                   0
# ENSG00000186092                   0                   0                   0
# ENSG00000238009                   0                   0                   0
# ENSG00000239945                   0                   0                   0
#
# ...
