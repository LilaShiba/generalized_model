# %%
import node
import pandas as pd
import numpy as np
import collections
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/nuforc_reports.csv')
#df.head(5)

# %%
shapes = node.vect(list(df['shape']),True)
print(shapes.vector[0:5])
# Out:
# 3.87
# [19, 28, 24, 28, 4]

# %%
shapes.pdf_log_binning()

# %%
shapes.cum_distro()

# %%
max(shapes.vals)
shapes.pdf_linearBinning()

# %%
shapes.ctl()

# %%
print(shapes.entropy)
print(shapes.variance)
print(shapes.vector_mu)
print(shapes.std)
shapes.vector_norm[0:5]
# Out:
# 3.87
# 68.14035293307842
# 17.409843727179787
# 8.25471701108393
# [0.6551724137931034,
#  0.9655172413793104,
#  0.8275862068965517,
#  0.9655172413793104,
#  0.13793103448275862]

# %%
time_seen = node.vect(list(df['duration']),False,True)
time_seen.pdf_log_binning()
time_seen.cum_distro()
# Out:
# 3.82

# %%
#agent.df = agent.df.drop(agent.df[agent.df.duration > 100])

# %%
talky = list(df['text'])

# %%
#len(shapes.hist_cnt)
len(shapes.log_prob_vector)
# Out:
# 49
